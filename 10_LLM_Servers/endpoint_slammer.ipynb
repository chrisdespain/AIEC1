# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = os.environ["FIREWORKS_CHAT_MODEL"]

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# A woodchuck would “chuck” exactly as much wood as a woodchuck could if a woodchuck could chuck wood – that’s the classic tongue‑twister answer.
#
# If you want a (slightly more) scientific spin, a groundhog (the animal behind the name “woodchuck”) can move roughly 700 lb of dirt when it digs a burrow. If you apply that same muscle‑power to “chucking” wood instead of dirt, the joke estimate comes out to about 700 lb (≈ 0.5 cubic metres) of wood.
#
# So, in short: as much wood as a woodchuck could chuck… which is about seven hundred pounds, give or take!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 12: A wood chuck would chuck as much wood as a wood chuck could ...
# Response 22: A wood chuck would chuck as much wood as a wood chuck could ...
# Response 21: It’s a classic tongue‑twister, so the “real” answer is reall...
# Response 1: The classic tongue‑twister answer is a playful loop:
#
# > “A w...
# Response 23: The classic answer is a bit of a tongue‑twister: *“A woodchu...
# Response 9: The classic punchline is really the whole point of the tongu...
# Response 17: The classic, tongue‑in‑cheek answer is:
#
# > **“A woodchuck wo...
# Response 18: The classic punch‑line is usually given as a circular quip:
# ...
# Response 4: The classic tongue‑twister answer is a bit of a play on word...
# Response 10: A classic tongue‑twister calls for a classic answer:
#
# **“A w...
# Response 5: A woodchuck would chuck **about 700 lb (≈ 320 kg) of wood** ...
# Response 7: It’s the classic tongue‑twister: a woodchuck can’t really ch...
# Response 20: The classic tongue‑twister answer is:
#
# > *A woodchuck would ...
# Response 19: The classic “tongue‑twister” answer is:
#
# > *A woodchuck woul...
# Response 11: The classic tongue‑twister answer is a bit of a play on word...
# Response 6: The classic tongue‑twister answer is a circular one:
#
# *“A ...
# Response 8: The classic “How much wood would a wood‑chuck chuck?” line i...
# Response 16: A woodchuck would chuck **exactly as much wood as a woodchuc...
# Response 2: The classic “tongue‑twister” answer is just a playful loop: ...
# Response 14: The classic tongue‑twister is really just a nonsense rhyme—t...
# Response 24: The classic tongue‑twister answer is:
#
# > *A woodchuck would ...
# Response 3: **The classic (and intended) answer** – the tongue‑twister i...
# Response 13: The classic tongue‑twister is really just a playful “what‑if...
# Response 15: The classic “how much wood could a wood chuck chuck?” line i...
